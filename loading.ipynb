    'http://rheissenberger.com/bac/era5/t2m_era5_201805_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201806_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201807_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201808_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201809_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201810_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201811_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201812_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201901_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201902_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201903_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201904_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201905_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201906_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201907_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201908_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201909_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201910_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201911_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_201912_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202001_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202002_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202003_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202004_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202005_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202006_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202007_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202008_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202009_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202010_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202011_025deg.nc',
    'http://rheissenberger.com/bac/era5/t2m_era5_202012_025deg.nc',]

# %%
import requests
import xarray as xr
import io

def load_via_url(urls):
        """
        Loads datasets from a list of URLs and concatenates them along the 'time' dimension.

        Args:
            urls (list): List of URLs pointing to dataset files.

        Returns:
            xr.Dataset: Xarray dataset containing concatenated data.
        """
        
        datasets = []
        for url in urls:
            print(f"Loading dataset from URL: {url}")
            dataset = xr.open_dataset(io.BytesIO(requests.get(url, allow_redirects=True).content), engine='h5netcdf')
            datasets.append(dataset)

        return xr.concat(datasets, dim='time')


def store_to_disk(file_name, data, file_path="./data/"):
    """
    Store data to disk in a specified folder.

    Parameters:
    - file_name (str): The name of the file to be saved.
    - data: The data to be stored.
    - folder_path (str, optional): The path to the folder where the file will be saved.
      Default is "data".
    """
    file = f"{file_path}{file_name}.nc"

    # first option
    write_job = data.to_netcdf(file, compute=False) #try zarr

    print(f"Writing to {file}")
    write_job.compute()

# %%
era5_add_ds = load_via_url(era5_add)
store_to_disk("era5_lsm_z", era5_add_ds)

cerra_add_ds = load_via_url(cerra_add)
store_to_disk("cerra_lsm_orog", cerra_add_ds)

# %%
era5_ds = load_via_url(era5)
store_to_disk("era5", era5_ds)

# %%
cerra_ds_01 = load_via_url(cerra_01)
store_to_disk("cerra01", cerra_ds_01)
# Out:
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201001_005deg.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 cerra_ds_01 = load_via_url(cerra_01)
#       2 store_to_disk("cerra01", cerra_ds_01)
#
# Cell In [4], line 19, in load_via_url(urls)
#      17 for url in urls:
#      18     print(f"Loading dataset from URL: {url}")
# ---> 19     dataset = xr.open_dataset(io.BytesIO(requests.get(url, allow_redirects=True).content), engine='h5netcdf')
#      20     datasets.append(dataset)
#      22 return xr.concat(datasets, dim='time')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/response.py:627, in HTTPResponse.stream(self, amt, decode_content)
#     625 else:
#     626     while not is_fp_closed(self._fp):
# --> 627         data = self.read(amt=amt, decode_content=decode_content)
#     629         if data:
#     630             yield data
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/response.py:566, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     563 fp_closed = getattr(self._fp, "closed", False)
#     565 with self._error_catcher():
# --> 566     data = self._fp_read(amt) if not fp_closed else b""
#     567     if amt is None:
#     568         flush_decoder = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/response.py:532, in HTTPResponse._fp_read(self, amt)
#     529     return buffer.getvalue()
#     530 else:
#     531     # StringIO doesn't like amt=None
# --> 532     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
i = 52
for url in cerra_01:
    cerra_ds = load_via_url([url])
    store_to_disk("cerra0"+str(i), cerra_ds)
    i+=1
# Out:
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201304_005deg.nc
# Writing to ./data/cerra052.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201305_005deg.nc
# Writing to ./data/cerra053.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201306_005deg.nc
# Writing to ./data/cerra054.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201307_005deg.nc
# Writing to ./data/cerra055.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201308_005deg.nc
# Writing to ./data/cerra056.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201907_005deg.nc
# Writing to ./data/cerra0127.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201908_005deg.nc
# Writing to ./data/cerra0128.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201909_005deg.nc
# Writing to ./data/cerra0129.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201910_005deg.nc
# Writing to ./data/cerra0130.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201911_005deg.nc
# Writing to ./data/cerra0131.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_201912_005deg.nc
# Writing to ./data/cerra0132.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202001_005deg.nc
# Writing to ./data/cerra0133.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202002_005deg.nc
# Writing to ./data/cerra0134.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202003_005deg.nc
# Writing to ./data/cerra0135.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202004_005deg.nc
# Writing to ./data/cerra0136.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202005_005deg.nc
# Writing to ./data/cerra0137.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202006_005deg.nc
# Writing to ./data/cerra0138.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202007_005deg.nc
# Writing to ./data/cerra0139.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202008_005deg.nc
# Writing to ./data/cerra0140.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202009_005deg.nc
# Writing to ./data/cerra0141.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202010_005deg.nc
# Writing to ./data/cerra0142.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202011_005deg.nc
# Writing to ./data/cerra0143.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_202012_005deg.nc
# Writing to ./data/cerra0144.nc

# %%
ds = xr.open_dataset("./data/cerra034.nc")
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 801, latitude: 501, time: 248)
# Coordinates:
#   * longitude  (longitude) float32 -10.0 -9.95 -9.9 -9.85 ... 29.9 29.95 30.0
#   * latitude   (latitude) float32 60.0 59.95 59.9 59.85 ... 35.1 35.05 35.0
#   * time       (time) datetime64[ns] 2012-10-01 ... 2012-10-31T21:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-26 08:13:40 GMT by grib_to_netcdf-2.28.0: grib_to_n...
