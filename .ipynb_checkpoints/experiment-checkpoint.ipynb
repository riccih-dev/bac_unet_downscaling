# %%
#these imports only work, when running the experiment from root project folder
from downscaling.pipeline import DownscalingPipeline
from IPython.display import display

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Definition of Parameters and Hyperparamters
# Loads data_params file
#
# Set Hyperparameters

# %% [markdown]
# ## Data Preperation
# This steps consits of loading the dataset, preprocessing and data splitting step.

# %% [markdown]
# ### Data Loading
# Defintion of Data, Features, Years etc.
# Where do i get the data from

# %%
# load data
pipeline = DownscalingPipeline('standardized_anomalies')
era5, era5_lsm_orog = pipeline.load_era5()
cerra, cerra_lsm_orog = pipeline.load_cerra()

era5_backup, era5_lsm_orog_backup = era5.copy(), era5_lsm_orog.copy() 
cerra_backup, cerra_lsm_orog_backup = cerra.copy(), cerra_lsm_orog.copy()
# Out:
# Loading dataset from URL: http://rheissenberger.com/bac/era5/t2m_era5_200605_025deg.nc
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/backends/plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# Loading dataset from URL: http://rheissenberger.com/bac/era5/t2m_era5_lsm_geop_201801_025deg.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_200605_005deg.nc
# Loading dataset from URL: http://rheissenberger.com/bac/cerra/t2m_cerra_lsm_orog_201801_005deg.nc

# %%
# show data
print("ERA5 DS:")
display(era5)
display(era5_lsm_orog)
print("\nCERRA DS:")
display(cerra)
display(cerra_lsm_orog)

# %%
# to enable local debugging - crop ds
# needs to be done before preprocessing, otherwhise statistical values won't be accurate
crop_size_lon = 80
crop_size_lat = 100
crop_size_time = 24

era5_backup, era5_lsm_orog_backup = era5.copy(), era5_lsm_orog.copy()
cerra_backup, cerra_lsm_orog_backup = cerra.copy(), cerra_lsm_orog.copy()

era5 = era5.isel(
    longitude=slice(0, crop_size_lon),
    latitude=slice(0, crop_size_lat),
    time=slice(0, crop_size_time)
)

era5_lsm_orog = era5_lsm_orog.isel(
    longitude=slice(0, crop_size_lon),
    latitude=slice(0, crop_size_lat),
    time=slice(0, crop_size_time)
)

cerra = cerra.isel(
    longitude=slice(0, crop_size_lon),
    latitude=slice(0, crop_size_lat),
    time=slice(0, crop_size_time)
)

cerra_lsm_orog = cerra_lsm_orog.isel(
    longitude=slice(0, crop_size_lon),
    latitude=slice(0, crop_size_lat),
    time=slice(0, crop_size_time)
)

# %%
# show data
print("ERA5 DS:")
display(era5)
display(era5_lsm_orog)
print("\nCERRA DS:")
display(cerra)
display(cerra_lsm_orog)
# Out:
# ERA5 DS:
# <xarray.Dataset>
# Dimensions:    (longitude: 80, latitude: 100, time: 24)
# Coordinates:
#   * longitude  (longitude) float32 -25.0 -24.75 -24.5 ... -5.75 -5.5 -5.25
#   * latitude   (latitude) float32 75.0 74.75 74.5 74.25 ... 50.75 50.5 50.25
#   * time       (time) datetime64[ns] 2006-05-01 ... 2006-05-03T21:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 256.9 256.9 ... 284.7 284.6
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-26 06:55:03 GMT by grib_to_netcdf-2.28.0: grib_to_n...
# <xarray.Dataset>
# Dimensions:    (longitude: 80, latitude: 100, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 -25.0 -24.75 -24.5 ... -5.75 -5.5 -5.25
#   * latitude   (latitude) float32 75.0 74.75 74.5 74.25 ... 50.75 50.5 50.25
#   * time       (time) datetime64[ns] 2018-01-01T12:00:00
# Data variables:
#     lsm        (time, latitude, longitude) float32 1.0 1.0 1.0 ... 0.2981 0.3706
#     z          (time, latitude, longitude) float32 1.797e+04 1.783e+04 ... 320.6
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-15 13:10:31 GMT by grib_to_netcdf-2.28.0: grib_to_n...
# CERRA DS:
# <xarray.Dataset>
# Dimensions:    (longitude: 80, latitude: 100, time: 24)
# Coordinates:
#   * longitude  (longitude) float32 -10.0 -9.95 -9.9 -9.85 ... -6.15 -6.1 -6.05
#   * latitude   (latitude) float32 60.0 59.95 59.9 59.85 ... 55.15 55.1 55.05
#   * time       (time) datetime64[ns] 2006-05-01 ... 2006-05-03T21:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 281.3 281.3 ... 281.7 282.3
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-26 08:00:36 GMT by grib_to_netcdf-2.28.0: grib_to_n...
# <xarray.Dataset>
# Dimensions:    (longitude: 80, latitude: 100, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 -10.0 -9.95 -9.9 -9.85 ... -6.15 -6.1 -6.05
#   * latitude   (latitude) float32 60.0 59.95 59.9 59.85 ... 55.15 55.1 55.05
#   * time       (time) datetime64[ns] 2018-01-01T12:00:00
# Data variables:
#     lsm        (time, latitude, longitude) float32 0.0 0.0 0.0 ... 0.9998 0.8327
#     orog       (time, latitude, longitude) float32 0.2687 0.3937 ... 236.8 167.6
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-15 12:55:13 GMT by grib_to_netcdf-2.28.0: grib_to_n...

# %% [markdown]
# ### Data Preprocessing
# Explain shortly how the data is preprocessed. Both Metrics

# %%
preprocessed_lr_data, preprocessed_hr_data = pipeline.preprocess_data(era5, cerra, era5_lsm_orog, cerra_lsm_orog)

# %%
# show data 
print("ERA5 DS preprocessed:")
display(preprocessed_lr_data)

print("\nCERRA DS preprocessed:")
display(preprocessed_hr_data)
# Out:
# ERA5 DS preprocessed:
# <xarray.Dataset>
# Dimensions:    (longitude: 800, latitude: 500, time: 249)
# Coordinates:
#   * longitude  (longitude) float32 -10.0 -9.95 -9.9 -9.85 ... 29.85 29.9 29.95
#   * latitude   (latitude) float32 35.0 35.05 35.1 35.15 ... 59.85 59.9 59.95
#   * time       (time) datetime64[ns] 2006-05-01 ... 2018-01-01T12:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 0.5992 0.6004 ... nan nan
#     lsm        (time, latitude, longitude) float32 nan nan nan ... 0.6348 0.6384
#     z          (time, latitude, longitude) float32 nan nan nan ... 0.6055 0.5304
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-26 06:55:03 GMT by grib_to_netcdf-2.28.0: grib_to_n...
# CERRA DS preprocessed:
# <xarray.Dataset>
# Dimensions:    (longitude: 800, latitude: 500, time: 249)
# Coordinates:
#   * longitude  (longitude) float32 -10.0 -9.95 -9.9 -9.85 ... 29.85 29.9 29.95
#   * latitude   (latitude) float32 35.0 35.05 35.1 35.15 ... 59.85 59.9 59.95
#   * time       (time) datetime64[ns] 2006-05-01 ... 2018-01-01T12:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 0.5846 0.5857 ... nan nan
#     lsm        (time, latitude, longitude) float32 nan nan nan ... -1.215 -1.215
#     orog       (time, latitude, longitude) float32 nan nan ... -0.6134 -0.6136
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-26 08:00:36 GMT by grib_to_netcdf-2.28.0: grib_to_n...

# %% [markdown]
# ### Data Splitting
# Explain how the data is splitted, which ratio. Evtl. store the data

# %%
# Perform Splitting
lr_train_data, lr_val_data, lr_test_data, hr_train_data, hr_val_data, hr_test_data = pipeline.split_data(normalized_lr_data, normalized_hr_data)

# %%
# Calculate ratios
total_lr_data = len(normalized_lr_data.time)
total_hr_data = len(normalized_hr_data.time)

ratio_lr_train = len(lr_train_data.time) / total_lr_data
ratio_lr_val = len(lr_val_data.time) / total_lr_data
ratio_lr_test = len(lr_test_data.time) / total_lr_data

ratio_hr_train = len(hr_train_data.time) / total_hr_data
ratio_hr_val = len(hr_val_data.time) / total_hr_data
ratio_hr_test = len(hr_test_data.time) / total_hr_data

# Print ratios
print(f"Low-Resolution Data Ratios:")
print(f"Train: {ratio_lr_train:.2%}, Validation: {ratio_lr_val:.2%}, Test: {ratio_lr_test:.2%}")

print("\nHigh-Resolution Data Ratios:")
print(f"Train: {ratio_hr_train:.2%}, Validation: {ratio_hr_val:.2%}, Test: {ratio_hr_test:.2%}")

# %% [markdown]
# ## Model Setup
# This step consits of model creation and training.

# %% [markdown]
# ### Creation of the Model
# Explain Model, how input shape is defined

# %%
# create model 
model = pipeline.fit_model(lr_train_data, hr_train_data, lr_val_data, hr_val_data)
# Out:
# [<KerasTensor: shape=(None, 100, 80, 448) dtype=float32 (created by layer 'activation_7')>, <KerasTensor: shape=(None, 100, 80, 224) dtype=float32 (created by layer 'activation_5')>, <KerasTensor: shape=(None, 100, 80, 112) dtype=float32 (created by layer 'activation_3')>, <KerasTensor: shape=(None, 100, 80, 56) dtype=float32 (created by layer 'activation_1')>]
# Epoch 1/50
# 1/1 [==============================] - 14s 14s/step - loss: 0.7703 - val_loss: 44.6067
# Epoch 2/50
# 1/1 [==============================] - 13s 13s/step - loss: 0.8862 - val_loss: 1029.2690
# Epoch 3/50
# 1/1 [==============================] - 14s 14s/step - loss: 0.7896 - val_loss: 136.6916
# Epoch 4/50
# 1/1 [==============================] - 14s 14s/step - loss: 0.6294 - val_loss: 217.1951
# Epoch 5/50
# 1/1 [==============================] - 15s 15s/step - loss: 0.5250 - val_loss: 115.7794
# Epoch 6/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4591 - val_loss: 106.3081
# Epoch 7/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4680 - val_loss: 69.1696
# Epoch 8/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4455 - val_loss: 56.9923
# Epoch 9/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4476 - val_loss: 38.1792
# Epoch 10/50
# 1/1 [==============================] - 18s 18s/step - loss: 0.4700 - val_loss: 30.8426
# Epoch 11/50
# 1/1 [==============================] - 18s 18s/step - loss: 0.4471 - val_loss: 46.0134
# Epoch 12/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4593 - val_loss: 44.4947
# Epoch 13/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4518 - val_loss: 33.8463
# Epoch 14/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4548 - val_loss: 11.4886
# Epoch 15/50
# 1/1 [==============================] - 15s 15s/step - loss: 0.4320 - val_loss: 11.6092
# Epoch 16/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4398 - val_loss: 7.8261
# Epoch 17/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4360 - val_loss: 11.9961
# Epoch 18/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4320 - val_loss: 6.8608
# Epoch 19/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4177 - val_loss: 6.6732
# Epoch 20/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4190 - val_loss: 6.1473
# Epoch 21/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4466 - val_loss: 10.5298
# Epoch 22/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4849 - val_loss: 4.9213
# Epoch 23/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4476 - val_loss: 18.3086
# Epoch 24/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4589 - val_loss: 2.0042
# Epoch 25/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4185 - val_loss: 1.2703
# Epoch 26/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4187 - val_loss: 1.7510
# Epoch 27/50
# 1/1 [==============================] - 18s 18s/step - loss: 0.4328 - val_loss: 2.5597
# Epoch 28/50
# 1/1 [==============================] - 18s 18s/step - loss: 0.4442 - val_loss: 2.4445
# Epoch 29/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4378 - val_loss: 2.3988
# Epoch 30/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4728 - val_loss: 1.6263
# Epoch 31/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4179 - val_loss: 1.2006
# Epoch 32/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4248 - val_loss: 1.6051
# Epoch 33/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4497 - val_loss: 1.1641
# Epoch 34/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4435 - val_loss: 1.9760
# Epoch 35/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4180 - val_loss: 1.1162
# Epoch 36/50
# 1/1 [==============================] - 16s 16s/step - loss: 0.4252 - val_loss: 1.7597
# Epoch 37/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4140 - val_loss: 0.6951
# Epoch 38/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4201 - val_loss: 1.5010
# Epoch 39/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4262 - val_loss: 3.7335
# Epoch 40/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4375 - val_loss: 3.2716
# Epoch 41/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4140 - val_loss: 1.4868
# Epoch 42/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4103 - val_loss: 1.8068
# Epoch 43/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4178 - val_loss: 1.0497
# Epoch 44/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4424 - val_loss: 3.7928
# Epoch 45/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4805 - val_loss: 3.8384
# Epoch 46/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4214 - val_loss: 1.0860
# Epoch 47/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4085 - val_loss: 0.8286
# Epoch 48/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4115 - val_loss: 0.9731
# Epoch 49/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4123 - val_loss: 0.8786
# Epoch 50/50
# 1/1 [==============================] - 17s 17s/step - loss: 0.4267 - val_loss: 0.7175

# %% [markdown]
# ### Model's History Plot

# %%
pipeline.show_training_history()

# %% [markdown]
# ### Train Model
# test different hyperparameters, maybe explain them in markdown

# %%
result = pipeline.predict(lr_test_data)
# Out:
# WARNING:tensorflow:Keras is training/fitting/evaluating on array-like data. Keras may not be optimized for this format, so if your input data format is supported by TensorFlow I/O (https://github.com/tensorflow/io) we recommend using that to load a Dataset instead.
# 1/1 [==============================] - 1s 759ms/step

# %% [markdown]
# ## Prediction & Evaluation
# Last step unseen temperautre data predicted, plus evaluation

# %% [markdown]
# ### Prediction

# %%
import numpy as np

reshaped_output = np.squeeze(result)
reshaped_output = np.transpose(reshaped_output, (2, 1, 0))

# prediction
display(reshaped_output.shape)
# Out:
# (80, 100, 3)

# %%
hr_test_denormalized = pipeline.denormalize(hr_test_data)
pipeline.evaluate_prediction(hr_test_denormalized, reshaped_output)
# Out:
#        RMSE       MAE  Max Error      Bias
# 0  2.074967  1.613999  12.964813  1.541311

# %% [markdown]
# ### Evaluation

# %%
# show plots etc.
